# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic_df = pd.read_csv(r"C:\Users\KIIT\Desktop\100 Days of ML\titanic.csv")

# %%
titanic_df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 321         1213         0       3     Krekorian, Mr. Neshan    male  25.0
# 376         1268         1       3         Kink, Miss. Maria  female  22.0
# 204         1096         0       2  Andrew, Mr. Frank Thomas    male  25.0
# 349         1241         1       2    Walcroft, Miss. Nellie  female  31.0
# 125         1017         1       3  Cribb, Miss. Laura Alice  female  17.0
#
#      SibSp  Parch        Ticket     Fare  Cabin Embarked
# 321      0      0          2654   7.2292  F E57        C
# 376      2      0        315152   8.6625    NaN        S
# 204      0      0    C.A. 34050  10.5000    NaN        S
# 349      0      0  F.C.C. 13528  21.0000    NaN        S
# 125      0      1        371362  16.1000    NaN        S

# %%
sns.countplot(titanic_df,x='Survived',palette=["orange", "blue"])
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_10452\2191700032.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(titanic_df,x='Survived',palette=["orange", "blue"])
# <Axes: xlabel='Survived', ylabel='count'>

# %%
titanic_df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic_df['Embarked'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(titanic_df['Age'])
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(titanic_df['Age'],bins=20)
# Out:
# (array([11.,  5.,  7.,  9., 29., 42., 52., 45., 21., 22., 18., 19., 16.,
#          9., 11.,  6.,  8.,  1.,  0.,  1.]),
#  array([ 0.17  ,  3.9615,  7.753 , 11.5445, 15.336 , 19.1275, 22.919 ,
#         26.7105, 30.502 , 34.2935, 38.085 , 41.8765, 45.668 , 49.4595,
#         53.251 , 57.0425, 60.834 , 64.6255, 68.417 , 72.2085, 76.    ]),
#  <BarContainer object of 20 artists>)

# %%
sns.distplot(titanic_df['Age'])
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_10452\134107046.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic_df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(titanic_df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(titanic_df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
titanic_df['Age'].skew()
# Out:
# 0.4573612871503845
